# %% [markdown]
# # Adult Census Income — 데이터 준비 EDA
#
# Pandas / Polars 양쪽으로 로딩 결과를 비교하고, 결측치·중복을 처리한 뒤 기본 EDA를 수행한다.
# 로딩·클린 로직은 `src/data_loader.py` 에 재사용 가능한 함수로 분리되어 있다.

# %%
import sys
import time

sys.path.insert(0, "..")
from src.data_loader import basic_eda, clean_pandas, load_pandas, load_polars

# %% [markdown]
# ## Pandas vs Polars 로딩 비교

# %%
t0 = time.perf_counter()
pdf_raw = load_pandas()
pandas_sec = time.perf_counter() - t0

t0 = time.perf_counter()
pldf = load_polars()
polars_sec = time.perf_counter() - t0

print(f"Pandas 로딩: {pandas_sec:.3f}s, shape={pdf_raw.shape}")
print(f"Polars 로딩: {polars_sec:.3f}s, shape={pldf.shape}")
# Out:
# Pandas 로딩: 0.055s, shape=(32561, 15)
# Polars 로딩: 0.050s, shape=(32561, 15)

# %% [markdown]
# ## 결측치 · 중복 처리

# %%
print("결측치(원본):")
print(pdf_raw.isna().sum()[pdf_raw.isna().sum() > 0])

pdf = clean_pandas(pdf_raw)
print(f"\n중복 제거 후 shape: {pdf.shape}")
# Out:
# 결측치(원본):
# workclass         1836
# occupation        1843
# native_country     583
# dtype: int64
# [clean_pandas] 중복행 24건 제거
#
# 중복 제거 후 shape: (32537, 15)

# %% [markdown]
# ## 기본 EDA

# %%
basic_eda(pdf)
# Out:
# ============================================================
# shape: (32537, 15)
# ------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 32537 entries, 0 to 32536
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       30701 non-null  str
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  str
#  4   education_num   32537 non-null  int64
#  5   marital_status  32537 non-null  str
#  6   occupation      30694 non-null  str
#  7   relationship    32537 non-null  str
#  8   race            32537 non-null  str
#  9   sex             32537 non-null  str
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  31955 non-null  str
#  14  income          32537 non-null  str
# dtypes: int64(6), str(9)
# memory usage: 6.2 MB
# ------------------------------------------------------------
# 결측치 개수 (상위):
# occupation        1843
# workclass         1836
# native_country     582
# dtype: int64
# ------------------------------------------------------------
#                   count unique                 top   freq           mean  \
# age             32537.0    NaN                 NaN    NaN      38.585549
# workclass         30701      8             Private  22673            NaN
# fnlwgt          32537.0    NaN                 NaN    NaN  189780.848511
# education         32537     16             HS-grad  10494            NaN
# education_num   32537.0    NaN                 NaN    NaN      10.081815
# marital_status    32537      7  Married-civ-spouse  14970            NaN
# occupation        30694     14      Prof-specialty   4136            NaN
# relationship      32537      6             Husband  13187            NaN
# race              32537      5               White  27795            NaN
# sex               32537      2                Male  21775            NaN
# capital_gain    32537.0    NaN                 NaN    NaN    1078.443741
# capital_loss    32537.0    NaN                 NaN    NaN      87.368227
# hours_per_week  32537.0    NaN                 NaN    NaN      40.440329
# native_country    31955     41       United-States  29153            NaN
# income            32537      2               <=50K  24698            NaN
#
#                           std      min       25%       50%       75%  \
# age                 13.637984     17.0      28.0      37.0      48.0
# workclass                 NaN      NaN       NaN       NaN       NaN
# fnlwgt          105556.471009  12285.0  117827.0  178356.0  236993.0
# education                 NaN      NaN       NaN       NaN       NaN
# education_num        2.571633      1.0       9.0      10.0      12.0
# marital_status            NaN      NaN       NaN       NaN       NaN
# occupation                NaN      NaN       NaN       NaN       NaN
# relationship              NaN      NaN       NaN       NaN       NaN
# race                      NaN      NaN       NaN       NaN       NaN
# sex                       NaN      NaN       NaN       NaN       NaN
# capital_gain      7387.957424      0.0       0.0       0.0       0.0
# capital_loss       403.101833      0.0       0.0       0.0       0.0
# hours_per_week      12.346889      1.0      40.0      40.0      45.0
# native_country            NaN      NaN       NaN       NaN       NaN
# income                    NaN      NaN       NaN       NaN       NaN
#
#                       max
# age                  90.0
# workclass             NaN
# fnlwgt          1484705.0
# education             NaN
# education_num        16.0
# marital_status        NaN
# occupation            NaN
# relationship          NaN
# race                  NaN
# sex                   NaN
# capital_gain      99999.0
# capital_loss       4356.0
# hours_per_week       99.0
# native_country        NaN
# income                NaN
# ============================================================

# %%
pdf.to_parquet("../data/processed/adult_clean.parquet", index=False)
print("저장 완료: data/processed/adult_clean.parquet")
# Out:
# 저장 완료: data/processed/adult_clean.parquet
